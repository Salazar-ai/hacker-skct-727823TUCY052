# %% [markdown]
# # IoT Device Fingerprinter — Demo
# **Roll No:** 52 | **Student:** Varun V

# %%
import sys, datetime
print(f'Roll No: 52 | {datetime.datetime.now()}')
print(f'Python: {sys.version}')

# %% [markdown]
# ## Test Case 1 — Single IP (Router)

# %%
import subprocess, sys
r = subprocess.run([sys.executable, '../code/tool_main.py', '--ip', '10.41.2.37'], capture_output=True, text=True)
print(r.stdout or r.stderr)

# %% [markdown]
# **[PLACEHOLDER] Screenshot TC1:** `screenshots/tc1_single_ip.png`
#
# ![TC1](../screenshots/tc1_single_ip.png)

# %% [markdown]
# ## Test Case 2 — Subnet Scan

# %%
r = subprocess.run([sys.executable, '../code/run_tool.py', '--output', 'results.json'], capture_output=True, text=True)
print(r.stdout or r.stderr)

# %% [markdown]
# **[PLACEHOLDER] Screenshot TC2:** `screenshots/tc2_subnet_scan.png`
#
# ![TC2](../screenshots/tc2_subnet_scan.png)

# %% [markdown]
# ## Test Case 3 — Banner Grab

# %%
r = subprocess.run([sys.executable, '../code/tool_main.py', '--ip', '10.41.2.37', '--banner'], capture_output=True, text=True)
print(r.stdout or r.stderr)

# %% [markdown]
# **[PLACEHOLDER] Screenshot TC3:** `screenshots/tc3_banner_grab.png`
#
# ![TC3](../screenshots/tc3_banner_grab.png)

# %% [markdown]
# ## Analysis

# %%
r = subprocess.run([sys.executable, '../code/analyze_results.py', '--input', 'results.json'], capture_output=True, text=True)
print(r.stdout or r.stderr)
